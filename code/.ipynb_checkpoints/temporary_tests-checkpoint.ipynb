# %% [markdown]
# # Random tests

# %%
# %load_ext autoreload
# %autoreload 2
#%matplotlib inline

from matplotlib import pyplot as plt
import seaborn as sns

import os
import sys
import pickle

import numpy  as np
import pandas as pd

from pprint     import pprint as pp
from itertools  import product,combinations
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from plot_util import *

# %%
np.random.seed(3)
a_seller_pos = [0, 0.4]
a_buyer_pos = np.random.uniform(high=2*np.pi, size=12)

# %%
circle_plot( a_seller_pos, a_buyer_pos, a_color=None, seller_ind=None, ax=None )
plt.savefig('temp.pdf')
